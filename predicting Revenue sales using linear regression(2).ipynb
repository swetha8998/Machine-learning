# %% [markdown]
# # Predicting sales revenue using Machine Learning approach-linear regresion model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
revenue_data=pd.read_csv('C:/Users/SVAAS/Downloads/Advertising.csv')

# %%
revenue_data.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
X=revenue_data.iloc[:,1:-1].values

# %%
revenue_data
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
x
# Out:
# array([[230.1,  37.8,  69.2],
#        [ 44.5,  39.3,  45.1],
#        [ 17.2,  45.9,  69.3],
#        [151.5,  41.3,  58.5],
#        [180.8,  10.8,  58.4],
#        [  8.7,  48.9,  75. ],
#        [ 57.5,  32.8,  23.5],
#        [120.2,  19.6,  11.6],
#        [  8.6,   2.1,   1. ],
#        [199.8,   2.6,  21.2],
#        [ 66.1,   5.8,  24.2],
#        [214.7,  24. ,   4. ],
#        [ 23.8,  35.1,  65.9],
#        [ 97.5,   7.6,   7.2],
#        [204.1,  32.9,  46. ],
#        [195.4,  47.7,  52.9],
#        [ 67.8,  36.6, 114. ],
#        [281.4,  39.6,  55.8],
#        [ 69.2,  20.5,  18.3],
#        [147.3,  23.9,  19.1],
#        [218.4,  27.7,  53.4],
#        [237.4,   5.1,  23.5],
#        [ 13.2,  15.9,  49.6],
#        [228.3,  16.9,  26.2],
#        [ 62.3,  12.6,  18.3],
#        [262.9,   3.5,  19.5],
#        [142.9,  29.3,  12.6],
#        [240.1,  16.7,  22.9],
#        [248.8,  27.1,  22.9],
#        [ 70.6,  16. ,  40.8],
#        [292.9,  28.3,  43.2],
# ...

# %%
Y=revenue_data.iloc[:,-1].values

# %%
y
# Out:
# array([22.1, 10.4,  9.3, 18.5, 12.9,  7.2, 11.8, 13.2,  4.8, 10.6,  8.6,
#        17.4,  9.2,  9.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. , 12.5,
#         5.6, 15.5,  9.7, 12. , 15. , 15.9, 18.9, 10.5, 21.4, 11.9,  9.6,
#        17.4,  9.5, 12.8, 25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7, 12.9,
#         8.5, 14.9, 10.6, 23.2, 14.8,  9.7, 11.4, 10.7, 22.6, 21.2, 20.2,
#        23.7,  5.5, 13.2, 23.8, 18.4,  8.1, 24.2, 15.7, 14. , 18. ,  9.3,
#         9.5, 13.4, 18.9, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9,
#        14.2,  5.3, 11. , 11.8, 12.3, 11.3, 13.6, 21.7, 15.2, 12. , 16. ,
#        12.9, 16.7, 11.2,  7.3, 19.4, 22.2, 11.5, 16.9, 11.7, 15.5, 25.4,
#        17.2, 11.7, 23.8, 14.8, 14.7, 20.7, 19.2,  7.2,  8.7,  5.3, 19.8,
#        13.4, 21.8, 14.1, 15.9, 14.6, 12.6, 12.2,  9.4, 15.9,  6.6, 15.5,
#         7. , 11.6, 15.2, 19.7, 10.6,  6.6,  8.8, 24.7,  9.7,  1.6, 12.7,
#         5.7, 19.6, 10.8, 11.6,  9.5, 20.8,  9.6, 20.7, 10.9, 19.2, 20.1,
# ...

# %%
sns.barplot(x='TV',y='sales',data=revenue_data)
# Out:
# C:\Users\SVAAS\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x='radio',y='sales',data=revenue_data)
# Out:
# C:\Users\SVAAS\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x='newspaper',y='sales',data=revenue_data)
# Out:
# C:\Users\SVAAS\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
len(X_train)
# Out:
# 140

# %%
len(X_test)
# Out:
# 60

# %%
lr.intercept_
# Out:
# 2.8802552863313267

# %%
Y_pred=lr.predict(X_test)

# %%
test_pred=pd.DataFrame({'actual':Y_test,'predicted':np.round(Y_pred,2),'residuals':Y_test-Y_pred})

# %%
test_pred
# Out:
#     actual  predicted  residuals
# 0     11.3      10.06   1.241333
# 1      8.4       7.43   0.966812
# 2      8.7       6.95   1.746943
# 3     25.4      24.17   1.231254
# 4     11.7      11.98  -0.281720
# 5      8.7       6.54   2.155353
# 6      7.2      13.19  -5.994268
# 7     13.2      14.90  -1.702403
# 8      9.2      11.08  -1.876753
# 9     16.6      16.25   0.349383
# 10    24.2      23.01   1.191884
# 11    10.6       9.12   1.479279
# 12    10.5      10.29   0.206577
# 13    15.6      15.37   0.229034
# 14    11.8      11.62   0.176035
# 15    13.2      12.11   1.094257
# 16    17.4      18.55  -1.150308
# 17     1.6      10.86  -9.258109
# 18    14.7      16.14  -1.438799
# 19    17.0      17.20  -0.202814
# 20    26.2      24.25   1.945301
# 21    10.3       9.44   0.861302
# 22    14.9      15.13  -0.234194
# 23    12.9      12.41   0.487162
# 24     8.1       5.67   2.430261
# 25    15.2      15.24  -0.038767
# 26    12.6      12.19   0.412124
# ...

# %%
X_train
# Out:
# array([[265.2,   2.9,  43. ],
#        [197.6,   3.5,   5.9],
#        [218.5,   5.4,  27.4],
#        [147.3,  23.9,  19.1],
#        [171.3,  39.7,  37.7],
#        [217.7,  33.5,  59. ],
#        [262.7,  28.8,  15.9],
#        [163.5,  36.8,   7.4],
#        [100.4,   9.6,   3.6],
#        [ 76.3,  27.5,  16. ],
#        [184.9,  43.9,   1.7],
#        [134.3,   4.9,   9.3],
#        [273.7,  28.9,  59.7],
#        [296.4,  36.3, 100.9],
#        [ 96.2,  14.8,  38.9],
#        [109.8,  47.8,  51.4],
#        [255.4,  26.9,   5.5],
#        [204.1,  32.9,  46. ],
#        [240.1,  16.7,  22.9],
#        [193.7,  35.4,  75.6],
#        [191.1,  28.7,  18.2],
#        [ 89.7,   9.9,  35.7],
#        [ 43. ,  25.9,  20.5],
#        [ 38.2,   3.7,  13.8],
#        [ 13.1,   0.4,  25.6],
#        [239.3,  15.5,  27.3],
#        [ 17.2,  45.9,  69.3],
#        [210.7,  29.5,   9.3],
#        [ 25.6,  39. ,   9.3],
#        [177. ,   9.3,   6.4],
#        [206.9,   8.4,  26.4],
# ...

# %%
Y_train
# Out:
# array([12.7, 11.7, 12.2, 14.6, 19. , 19.4, 20.2, 18. , 10.7, 12. , 20.7,
#        11.2, 20.8, 23.8, 11.4, 16.7, 19.8, 19. , 15.9, 19.2, 17.3, 10.6,
#         9.6,  7.6,  5.3, 15.7,  9.3, 18.4,  9.5, 12.8, 12.9,  8.6, 17.3,
#        11. ,  9.7, 11.8, 27. ,  6.6, 22.2, 14.1,  7.3,  9.9, 11.4, 22.1,
#        11.5, 13.4, 16.9, 18. , 12.2, 17.1, 22.3,  9.7, 14.8, 15.2,  9.7,
#        13.3, 15.5, 10.3, 11.6, 18. , 22.4,  5.3, 20.7, 22.6, 11.7,  6.9,
#        18.5, 12.2, 11.9, 25.5, 11.8, 18.9, 21.7,  7. ,  3.2, 14.5, 15.3,
#         7.3, 13.4, 17.4,  6.6, 14.8, 12.8, 13.2,  9.3, 10.4, 15.5, 14.9,
#        20.7, 19.2,  5.7, 11.7, 24.4, 10.1, 19.6, 21.2, 10.1, 24.7,  9.5,
#        18.9, 14.6, 11.6, 11.9,  8. ,  8.8, 20.2,  9.6, 20.1, 15. , 25.4,
#        10.5, 17.2, 11.3, 11. , 12.6, 10.9, 19.6,  8.8, 14.2, 12. , 11.9,
#        12.3, 15.9, 11.5, 10.8, 21.5, 23.8, 10.9, 12.9, 18.3, 16. , 25.4,
#        12.5, 10.6, 14.7, 13.4,  5.9,  9.4, 23.2,  7.6])

# %%
from sklearn import metrics

# %%
rmse=np.sqrt(metrics.mean_squared_error(Y_test,Y_pred))

# %%
round(rmse,2)
# Out:
# 1.92

# %%
metrics.r2_score(Y_test,Y_pred)
# Out:
# 0.8649018906637793
